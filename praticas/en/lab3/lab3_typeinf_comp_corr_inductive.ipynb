# %% [markdown]
# # Exercises on type inference, function composition, program correctness and inductive reasoning

# %% [markdown]
# ## Type inference and function composition

# %% [markdown]
# ### 🔹 Exercise 1:
#
# Consider the following function definitions:
#
# ```OCaml
# (1) let f = fun x -> x
# (2) let g = fun h -> fun x -> h x
# (3) let k u = u (g (fun x -> f x) 0)
# ```

# %% [markdown]
# What is the type of each function?

# %%
(* Complete here: *)
(1) 
(2) 
(3)

# %% [markdown]
# ### 🔹 Exercise 2:
#
# Using the previously defined functions, construct expressions of type:
#
# ```OCaml
# (1) `int`
# (2) `bool`
# (3) `int -> int`
# (4) `'a -> 'a`
# ```

# %%
(* Complete here: *)
(1) 
(2) 
(3)
(4)

# %% [markdown]
# ### 🔹 Exercise 3:
#
# Justify, using a system of equations, the type of the following expression:
#
# ```OCaml
# (fun x ->
#     if x > 3 then
#         string_of_int x
#     else
#         "too few")
#     4;;
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## Program correctness: pre and post-conditions

# %% [markdown]
# ### 🔹 Exercise 4:
#
# Given the following function definitions, indicate the preconditions and postconditions of each one:
#
# ```OCaml
# (1) let rec fact x =
#     if x = 0 then
#       1
#     else x * fact (x - 1)
# ```

# %% [markdown]
# ⚠️ **Answer:** [Complete here]

# %% [markdown]
# ```OCaml
# (2) let rec gcd u v =
#     if v = 0 then
#       u
#     else gcd v (u mod v)
# ```

# %% [markdown]
# ⚠️ **Answer:** [Complete here]

# %% [markdown]
# ```OCaml
# (3) let division a b =
#       let rec division' q r =
#         if r < b then
#           (q, r)
#         else
#           division' (q + 1) (r - b)
#       in
#       division' 0 a
# ```

# %% [markdown]
# ⚠️ **Answer:** [Complete here]

# %% [markdown]
# ---

# %% [markdown]
# ## Recursive Functions

# %% [markdown]
# ### 🔹 Exercise 5:
#
# Consider a corridor with two lanes and a total length of $\mathcal{N}$ units.
# To simplify the illustration of the problem, we will consider the road as a rectangle with dimensions $2 \times \mathcal{N}$ .
#
# The municipality responsible for this road has decided to pave it with advertisements, thus avoiding the need to charge tolls for users.
# For logistical reasons, all advertisement panels must have the same size and be rectangles of dimensions $2 \times 1$. This means that the road can be covered widthwise with a single panel or lengthwise by placing two advertisement panels together.
#
# The following image shows 4 of the 13 distinct ways to pave a road of length 6 units:
#
# ![Road Paving](https://lap-2024.github.io/praticas/road.png)
#
# How many distinct ways are there to pave a road of length $\mathcal{N}$ units?
# Define the following OCaml function, where the argument is the road length and the result is the total number of distinct paving arrangements:
#
# ```ocaml
# val road : int -> int
# ```
#
# **Example**: For a road of 42 units in length, there are 433,494,437 distinct ways to pave it.

# %%
let road n = 
  (* Complete here: *)

# %% [markdown]
# ### 🔹 Exercise 6: Honey, Induction Changed the House
#
# Ana and Bernardo are about to start renovating their kitchen. One of the ideas they would like to implement is placing a tile border along the entire wall. Being both great lovers of interior decoration, they have agreed on the following aesthetic rules:
#
# 1. the tiles in the border must be either red or black;
# 2. each block of red tiles must consist of at least 3 consecutive red tiles;
# 3. two blocks of red tiles (which may be of different sizes) must be separated by at least one black tile.
#
# Before starting the work, and knowing the length of the border, Ana and Bernardo would like to know how many distinct ways there are to fill the border while respecting the rules they have established.
# Taking a border of size 7 as an example, there are the following 17 different ways to fill the border:
#
# <img src="https://lap-2024.github.io/trabalhos/trab1/rouge_noir.png">
#
# #### Task
#
# In this exercise your task is to define a recursive, mathematical function that models this problem. It is, therefore, a function that takes the size of the border as an argument and returns the number of distinct ways to fill it, according to Ana and Bernardo's rules. You should then implement this function in OCaml. The OCaml function should have the following signature:
#
# ```ocaml
#   val tiles: int -> int
# ```
#
# You may use any auxiliary functions you find convenient.
#
# #### Examples
#
# 1. A border of size 8 can be filled in 27 distinct ways.
# 2. A border of size 10 can be filled in 72 distinct ways.
# 3. A border of size 15 can be filled in 798 distinct ways.
# 4. A border of size 20 can be filled in 8855 distinct ways.

# %%
let tiles n = 
  (* Complete here: *)
