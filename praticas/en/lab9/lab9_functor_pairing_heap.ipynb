# %% [markdown]
# # Functors - Modular Data Structures

# %% [markdown]
# ## Pairing Heap as a Functor

# %% [markdown]
# ### 🔹 Exercise 1 ⭐️
#
# Recall the [Notebook](https://lap-2025.github.io/praticas/pt/lab7/lab7_pairing_heap.ipynb) from last week.
#
# Complete the following signature `S` that will serve as the interface for the *Pairing Heap* data structure. You should complete this signature based on the operations on a *Pairing Heap*. Compared to last week's *Notebook*, we have only added the `is_empty` operation, which checks whether a given heap is empty or not.

# %%
module type S = 
  sig
    (** The type of heap elements. *)
    type elt
    
    (** The type of the heap. *)
    type t
    
    (** The empty heap. *)
    val create : (* Complete here *) unit 
    
    (** Checks whether a given heap is empty. *)
    val is_empty : (* Complete here *) unit
    
    (** Returns the minimum element of the heap, or [None] if the heap is empty. *)
    val find_min : (* Complete here *) unit 
    
    (** Merges two heaps. *)
    val merge : (* Complete here *) unit 
    
    (** Adds a new element to the heap. *)
    val add : (* Complete here *) unit 
      
    (** [delete_min h] returns a new heap containing all elements of [h] except the minimum value. If the heap is empty, returns the empty heap. *)
    val delete_min : (* Complete here *) unit     
end

# %% [markdown]
# ### 🔹 Exercise 2 ⭐️
#
# Complete the following signature `ORD`. This signature should represent values of a type `t` equipped with an ordering relation. You should add a function `leq` such that `leq x y` returns `true` if `x` is less than or equal to `y`; `false` otherwise.

# %%
module type ORD = sig
  type t
  (* Complete here *)
end

# %% [markdown]
# ### 🔹 Exercise 3 ⭐️⭐️
#
# Use the signatures `S` and `ORD` defined above to create a functorial implementation of a *Pairing Heap* structure. You should complete the indicated operations so that the following constraint holds:
#
# ```OCaml
# S with type elt = O.t
# ```

# %%
module Make (O : ORD) : S with type elt = O.t = 
  struct
    type elt = (* Complete here *)

    type tree = (* Complete here *)

    type t = 
      | E 
      | N of tree

    let create = E

    let is_empty h =
      assert false (* Complete here *)

    let find_min h =
      match h with
      | E -> None
      | N _ -> assert false (* Complete here *)

    let merge h1 h2 =
      match h1, h2 with
      | E, h -> h
      | h, E -> h
      | N _, N _ -> assert false (* Complete here *)

    let add x h =
      assert false (* Complete here *)

    let rec merge_list h =
      match h with
      | [] -> E
      | [ t ] -> N t
      | t1 :: t2 :: r -> merge (merge (N t1) (N t2)) (merge_list r)

    let delete_min h =
      match h with
      | E -> E
      | N _ -> assert false (* Complete here *)
  end

# %% [markdown]
# ## Application: Modular HeapSort

# %% [markdown]
# ### 🔹 Exercise 4 ⭐️⭐️⭐️
#
# Use the functor `Make` from the previous exercise to define a modular implementation of the `heap sort` algorithm on lists. The algorithm works as follows:
#
# 1. Insert all elements of the list into a heap;
# 2. Recursively remove the minimum element from the heap until it is empty. As each new element is removed from the heap, it should be added to a new list;
# 3. The new list contains the elements in reverse order. Reverse this list to obtain a permutation of list `l` sorted in natural order.
#
# Start by defining the module `Heap`, which should be an instance of the functor `Make` defined above. Try it with different element types, for example, integers or strings.
#
# **Hint:** begin by defining two auxiliary functions `heapify` and `de_heapify` corresponding, respectively, to steps 1 and 2 described above.

# %%
module Heap (* Complete here *)

let heapsort l =
  assert false (* Complete here *)

# %%
(* Unit tests *)
