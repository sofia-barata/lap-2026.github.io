# %% [markdown]
# # Estado mutável e Memoisation
#
# ### 🔹 Exercício 1 ⭐️
#
# Considere a função de Fibonacci, que é definida como:
#
# ```ocaml
# let rec fib n =
#   if n <= 1 then n
#   else fib (n - 1) + fib (n - 2)
# ```
#
# Utilize a técnica demonstrada na aula teórica para otimizar esta função usando memoization (Landi's knot). Tente que o código que gere a memória para armazenar os resultados já calculados e o código da função propriament dita fiquem separados. Teste com vários inputs diferentes para comprovar a melhoria de desempenho.

# %%
(* Testes unitários *)

# %% [markdown]
# ### 🔹 Exercício 2 ⭐️
#
# A técnica que utiliza memoisation na pergunta anterior é particular para a função de Fibonacci. Desenvolva uma forma genérica que optimizar qualquer função sem escrever código específico para cada função. Teste a sua implementação com a função de Fibonacci e outras funções recursivas, como a função de factorial. Dica: use um parâmetro adicional para indicar a função a optimizar e a variável que é usada para interseptar as chamadas recursivas.

# %%
(* testes unitários *)
